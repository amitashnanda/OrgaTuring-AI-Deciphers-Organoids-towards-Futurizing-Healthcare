# %% [markdown]
# # OrgaTuring: AI Deciphers Organoids towards Futurizing Healthcare

# %% [markdown]
# - CNN with Interpretability Pipeline to localize, quantize, and classify Organoid Inflamed and Non-Inflamed images

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
from tensorflow.python.client import device_lib
devices = device_lib.list_local_devices()

def sizeof_fmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f%s%s" % (num, 'Yi', suffix)

for d in devices:
    t = d.device_type
    name = d.physical_device_desc
    l = [item.split(':',1) for item in name.split(", ")]
    name_attr = dict([x for x in l if len(x)==2])
    dev = name_attr.get('name', 'Unnamed device')
    print(f" {d.name} || {dev} || {t} || {sizeof_fmt(d.memory_limit)}")
# Out:
#  /device:CPU:0 || Unnamed device || CPU || 256.0 MiB
#  /device:XLA_CPU:0 || Unnamed device || XLA_CPU || 16.0 GiB
#  /device:XLA_GPU:0 || Unnamed device || XLA_GPU || 16.0 GiB
#  /device:XLA_GPU:1 || Unnamed device || XLA_GPU || 16.0 GiB
#  /device:XLA_GPU:2 || Unnamed device || XLA_GPU || 16.0 GiB
#  /device:XLA_GPU:3 || Unnamed device || XLA_GPU || 16.0 GiB
#  /device:GPU:0 ||  GeForce GTX 1080 Ti || GPU || 10.1 GiB
#  /device:GPU:1 ||  GeForce GTX 1080 Ti || GPU || 10.1 GiB
#  /device:GPU:2 ||  GeForce GTX 1080 Ti || GPU || 10.1 GiB
#  /device:GPU:3 ||  GeForce GTX 1080 Ti || GPU || 10.1 GiB
# 2022-09-28 12:09:07.760414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-09-28 12:09:07.761501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-09-28 12:09:07.762545: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 2 with properties:
# pciBusID: 0000:81:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-09-28 12:09:07.763556: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 3 with properties:
# pciBusID: 0000:82:00.0 name: GeForce GTX 1080 Ti computeCapability: 6.1
# coreClock: 1.582GHz coreCount: 28 deviceMemorySize: 10.92GiB deviceMemoryBandwidth: 451.17GiB/s
# 2022-09-28 12:09:07.779822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2022-09-28 12:09:07.781115: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-09-28 12:09:07.782267: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2022-09-28 12:09:07.782759: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2022-09-28 12:09:07.782798: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2022-09-28 12:09:07.783417: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2022-09-28 12:09:07.783995: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2022-09-28 12:09:07.790981: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1703] Adding visible gpu devices: 0, 1, 2, 3
# 2022-09-28 12:09:07.794595: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1102] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-09-28 12:09:07.794610: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1108]      0 1 2 3
# 2022-09-28 12:09:07.795164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 0:   N Y N N
# 2022-09-28 12:09:07.795173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 1:   Y N N N
# 2022-09-28 12:09:07.795176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 2:   N N N Y
# 2022-09-28 12:09:07.795180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1121] 3:   N N Y N
# 2022-09-28 12:09:07.799380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/device:GPU:0 with 10377 MB memory) -> physical GPU (device: 0, name: GeForce GTX 1080 Ti, pci bus id: 0000:02:00.0, compute capability: 6.1)
# 2022-09-28 12:09:07.800430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/device:GPU:1 with 10378 MB memory) -> physical GPU (device: 1, name: GeForce GTX 1080 Ti, pci bus id: 0000:03:00.0, compute capability: 6.1)
# 2022-09-28 12:09:07.801466: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/device:GPU:2 with 10378 MB memory) -> physical GPU (device: 2, name: GeForce GTX 1080 Ti, pci bus id: 0000:81:00.0, compute capability: 6.1)
# 2022-09-28 12:09:07.802492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1247] Created TensorFlow device (/device:GPU:3 with 10378 MB memory) -> physical GPU (device: 3, name: GeForce GTX 1080 Ti, pci bus id: 0000:82:00.0, compute capability: 6.1)

# %%
#import packages
import pandas as pd       
import matplotlib as mat
import matplotlib.pyplot as plt    
import numpy as np
import seaborn as sns
import splitfolders
# %matplotlib inline

pd.options.display.max_colwidth = 100

import random
import os
import sklearn

from numpy.random import seed
seed(42)

random.seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
os.environ['TF_DETERMINISTIC_OPS'] = '1'

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2
from skimage.io import imread
from skimage.transform import resize
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout
from tensorflow.keras.layers import Input, Flatten, SeparableConv2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
import glob
import cv2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from skimage.io import imread
from tensorflow.keras.applications import vgg16

from tensorflow.random import set_seed
set_seed(42)

import warnings
warnings.filterwarnings('ignore')

color = sns.color_palette()
# %matplotlib inline
# %config InlineBackend.figure_format="svg"

# %%
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:1', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:2', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:XLA_GPU:3', device_type='XLA_GPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')]

# %%
IMG_SIZE = 224
# BATCH = 32
BATCH = 64
SEED = 42
GPUS = ["GPU:0", "GPU:1", "GPU:2","GPU:3"]

# %%
strategy = tf.distribute.MirroredStrategy(GPUS)
print('Number of devices: %d' % strategy.num_replicas_in_sync)
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Number of devices: 4

# %%
batch_size = BATCH * strategy.num_replicas_in_sync

# %%
batch_size
# Out:
# 256

# %% [markdown]
# - Splitting the Dataset into train, test, and valid

# %%
# # Creating Train, Test, and Valid Dataset
# input_folder = "../../../aman/Updated_Dataset_2D/Sorted/"

# %%
# # Split with a ratio.

# # To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
# # Train, val, test
# splitfolders.ratio(input_folder, output="./dataset/raw_dataset_update/", 
#                    seed=42, ratio=(.7, .15, .15), 
#                    group_prefix=None) # default values

# %%
# train_dir = os.path.join("./dataset/aug_dataset_update/train/")
# valid_dir = os.path.join('./dataset/aug_dataset_update/val/')
# test_dir = os.path.join('./dataset/aug_dataset_update/test/')

# train_i_dir = os.path.join('./dataset/aug_dataset_update/train/Inflamed/')
# train_ni_dir = os.path.join('./dataset/aug_dataset_update/train/NonInflamed/')

# valid_i_dir = os.path.join('./dataset/aug_dataset_update/val/Inflamed/')
# valid_ni_dir = os.path.join('./dataset/aug_dataset_update/val/NonInflamed')

# test_i_dir = os.path.join('./dataset/aug_dataset_update/test/Inflamed/')
# test_ni_dir = os.path.join('./dataset/aug_dataset_update/test/NonInflamed')
train_dir = os.path.join("./dataset/raw_dataset/train/")
valid_dir = os.path.join('./dataset/raw_dataset/val/')
test_dir = os.path.join('./dataset/raw_dataset/test/')

train_i_dir = os.path.join('./dataset/raw_dataset/train/Inflamed/')
train_ni_dir = os.path.join('./dataset/raw_dataset/train/NonInflamed/')

valid_i_dir = os.path.join('./dataset/raw_dataset/val/Inflamed/')
valid_ni_dir = os.path.join('./dataset/raw_dataset/val/NonInflamed')

test_i_dir = os.path.join('./dataset/raw_dataset/test/Inflamed/')
test_ni_dir = os.path.join('./dataset/raw_dataset/test/NonInflamed')

# %%
train_i_names = os.listdir(train_i_dir)
print(train_i_names [:10])

train_ni_names  = os.listdir(train_ni_dir)
print(train_ni_names [:10])

valid_i_names = os.listdir(valid_i_dir)
print(valid_i_names[:10])

valid_ni_names = os.listdir(valid_ni_dir)
print(valid_ni_names[:10])

test_i_names = os.listdir(test_i_dir)
print(test_i_names[:10])

test_ni_names = os.listdir(test_ni_dir)
print(test_ni_names[:10])
# Out:
# ['CD 11 ILEUM.tif', 'CD11-Il-I_QS_2471.tif', 'CD42-I-I P0 190905 4x .tif', 'CD11-Il-I_QS_2470.tif', 'CD42-I-I P5 191002 10X.tif', 'CD12-LC-I_QS_2472.tif', 'CD11 IL-I-QS_2496 20x 190603.tif', 'CD41-I-I P2 190909 4x .tif', 'CD11 IL-I-QS_2503 40x 190603.tif', 'CD13-Il-I_QS_2477.tif']
# ['CD11-LC-NI P12 190905 4x.tif', 'CD24-I-NI P1 190620 4X.tif', 'CD50-I-NI P4 200304 10X.JPG', 'CD27-R-NI P3 190711 10X.tif', 'CD19-LC-NI P6 191002 10X 1.tif', 'CD50-R p3 191210 4X.tif', 'CD12-Il-NI_QS_2474.tif', 'CD21-I-NI P2 190813 10X.tif', 'CD12 ILEUM NI 4.tif', 'CD47-C-NI P0 191004 10X.tif']
# ['CD11 IL-I-QS_2498 20x 190603.tif', 'CD62-I-I P1 202026 10X.JPG', 'CD41-I-I P2 190909 10x .tif', 'CD11 IL-I-QS_2500 40x 190603.tif', 'CD63-I-I P3 200318 4X.JPG', 'CD11 IL-I-QS_2497 20x 190603.tif', 'CD42-I-I P2 190920 4X.tif', 'CD62-I-I P2 200304 10X.JPG', 'CD11 IL-I-QS_2494 10x 190603.tif']
# ['CD30-LC-NI P13 191003 10X 1.tif', 'CD13-LC-NI_QS_2482.tif', 'CD62-R-NI P1 10x 02.23.20.JPG', 'CD12 IL-NI-QS_2512 40x 190603.tif', 'CD47-I-NI P0 191007 10X.tif', 'CD32-I p9 10x 9-19-19.tif', 'CD62-R-NI P0 200219 10X.JPG', 'CD30-LC-NI P1 190715 4X.tif', 'CD13-LC-NI P4 190602 4x.tif', 'CD63-LC-NI P3 200309 4X.JPG']
# ['CD11 IL-I-QS_2499 20x 190603.tif', 'CD11 ILEUM Inf 3.tif', 'CD11-I-I P8 190719 4X.tif', 'CD62-I-I P2 200304 4X.JPG', 'CD11 ILEUM Inf 2.tif', 'CD11 IL-I-QS_2493 10x 190603.tif']
# ['CD12 IL-NI-QS_2505 20x 190603.tif', 'CD50-R-NI P0 191119 4X.tif', 'CD62-R-NI P1 5x 02.23.20.JPG', 'CD60-LC-NI P0 10x 01.17.19.JPG', 'CD19-LC-NI P0 190524 10x.tif', 'CD22-LC-NI P2 190708 4x .tif', 'CD62-R-NI P4 200313 4X.JPG', 'CD19-LC-NI P6 191002 20X 3.tif', 'CD26-LC P5 191201 4x.tif', 'CD23-LC-NI P3 190724 4X.tif']

# %%
print('total training i images:', len(os.listdir(train_i_dir)))
print('total training ni images:', len(os.listdir(train_ni_dir)))
print('total validation i images:', len(os.listdir(valid_i_dir)))
print('total validation ni images:', len(os.listdir(valid_ni_dir)))
print('total testing i images:', len(os.listdir(test_i_dir)))
print('total testing ni images:', len(os.listdir(test_ni_dir)))

num_train_i =  len(os.listdir(train_i_dir))
num_train_ni =  len(os.listdir(train_ni_dir))
num_val_i =  len(os.listdir(valid_i_dir))
num_val_ni =  len(os.listdir(valid_ni_dir))
num_test_i =  len(os.listdir(test_i_dir))
num_test_ni =  len(os.listdir(test_ni_dir))

total_train =num_train_i  + num_train_ni
total_val = num_val_i  + num_val_ni
total_test = num_test_i   + num_test_ni 

print("-----------------------------------------------------")
print("Total training images:", total_train)
print("Total validation images:", total_val)
print("Total testing images:", total_test)
# Out:
# total training i images: 34
# total training ni images: 251
# total validation i images: 9
# total validation ni images: 71
# total testing i images: 6
# total testing ni images: 37
# -----------------------------------------------------
# Total training images: 285
# Total validation images: 80
# Total testing images: 43

# %%
train_i = glob.glob(train_i_dir+"/*.*")
train_ni = glob.glob(train_ni_dir+"/*.*")
# train_i_names

# %%
valid_i = glob.glob(valid_i_dir+"/*.*")
valid_ni = glob.glob(valid_ni_dir+"/*.*")
# train_i_names

# %%
test_i = glob.glob(test_i_dir+"/*.*")
test_ni = glob.glob(test_ni_dir+"/*.*")
# train_i_names

# %%
train_list = [x for x in train_i]
train_list.extend([x for x in train_ni])

df_train = pd.DataFrame(np.concatenate([['Inflamed']*len(train_i) , ['NonInflamed']*len(train_ni)]), columns = ['class'])
df_train['image'] = [x for x in train_list]

# %%
valid_list = [x for x in valid_i]
valid_list.extend([x for x in valid_ni])

df_valid = pd.DataFrame(np.concatenate([['Inflamed']*len(valid_i) , ['NonInflamed']*len(valid_ni)]), columns = ['class'])
df_valid['image'] = [x for x in valid_list]

# %%
test_list = [x for x in test_i]
test_list.extend([x for x in test_ni])

df_test = pd.DataFrame(np.concatenate([['Inflamed']*len(test_i) , ['NonInflamed']*len(test_ni)]), columns = ['class'])
df_test['image'] = [x for x in test_list]

# %%
df_train
# Out:
#            class  \
# 0       Inflamed
# 1       Inflamed
# 2       Inflamed
# 3       Inflamed
# 4       Inflamed
# ..           ...
# 280  NonInflamed
# 281  NonInflamed
# 282  NonInflamed
# 283  NonInflamed
# 284  NonInflamed
#
#                                                                     image
# 0                    ./dataset/raw_dataset/train/Inflamed/CD 11 ILEUM.tif
# 1              ./dataset/raw_dataset/train/Inflamed/CD11-Il-I_QS_2471.tif
# 2         ./dataset/raw_dataset/train/Inflamed/CD42-I-I P0 190905 4x .tif
# 3              ./dataset/raw_dataset/train/Inflamed/CD11-Il-I_QS_2470.tif
# 4         ./dataset/raw_dataset/train/Inflamed/CD42-I-I P5 191002 10X.tif
# ..                                                                    ...
# 280  ./dataset/raw_dataset/train/NonInflamed/CD63-LC-NI P4 200316 10X.JPG
# 281   ./dataset/raw_dataset/train/NonInflamed/CD47-LC-NI P2 191017 4x.tif
# 282  ./dataset/raw_dataset/train/NonInflamed/CD26-LC-NI P3 191114 10X.tif
# 283   ./dataset/raw_dataset/train/NonInflamed/CD32-I-NI P0 190722 10X.tif
# 284    ./dataset/raw_dataset/train/NonInflamed/CD28-R-NI P2 190707 4X.tif
#
# [285 rows x 2 columns]

# %%
class_i = df_train[df_train['class'] == 'Inflamed']
class_ni = df_train[df_train['class'] == 'NonInflamed']

# %%
class_i
# Out:
#        class  \
# 0   Inflamed
# 1   Inflamed
# 2   Inflamed
# 3   Inflamed
# 4   Inflamed
# 5   Inflamed
# 6   Inflamed
# 7   Inflamed
# 8   Inflamed
# 9   Inflamed
# 10  Inflamed
# 11  Inflamed
# 12  Inflamed
# 13  Inflamed
# 14  Inflamed
# 15  Inflamed
# 16  Inflamed
# 17  Inflamed
# 18  Inflamed
# 19  Inflamed
# 20  Inflamed
# 21  Inflamed
# 22  Inflamed
# 23  Inflamed
# 24  Inflamed
# 25  Inflamed
# 26  Inflamed
# 27  Inflamed
# 28  Inflamed
# 29  Inflamed
# 30  Inflamed
# 31  Inflamed
# 32  Inflamed
# 33  Inflamed
#
#                                                                     image
# 0                    ./dataset/raw_dataset/train/Inflamed/CD 11 ILEUM.tif
# 1              ./dataset/raw_dataset/train/Inflamed/CD11-Il-I_QS_2471.tif
# 2         ./dataset/raw_dataset/train/Inflamed/CD42-I-I P0 190905 4x .tif
# 3              ./dataset/raw_dataset/train/Inflamed/CD11-Il-I_QS_2470.tif
# 4         ./dataset/raw_dataset/train/Inflamed/CD42-I-I P5 191002 10X.tif
# 5              ./dataset/raw_dataset/train/Inflamed/CD12-LC-I_QS_2472.tif
# 6   ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2496 20x 190603.tif
# 7         ./dataset/raw_dataset/train/Inflamed/CD41-I-I P2 190909 4x .tif
# 8   ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2503 40x 190603.tif
# 9              ./dataset/raw_dataset/train/Inflamed/CD13-Il-I_QS_2477.tif
# 10        ./dataset/raw_dataset/train/Inflamed/CD42-I-I P2 190920 10X.tif
# 11        ./dataset/raw_dataset/train/Inflamed/CD41-I-I P0 190830 10x.tif
# 12                 ./dataset/raw_dataset/train/Inflamed/CD11 ILEUM I .tif
# 13        ./dataset/raw_dataset/train/Inflamed/CD63-I-I P3 200318 10X.JPG
# 14  ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2504 40x 190603.tif
# 15        ./dataset/raw_dataset/train/Inflamed/CD62-I-I P3 200311 10X.JPG
# 16         ./dataset/raw_dataset/train/Inflamed/CD63-I-I P2 200313 4X.JPG
# 17        ./dataset/raw_dataset/train/Inflamed/CD11-I-I P8 190719 10X.tif
# 18       ./dataset/raw_dataset/train/Inflamed/CD41-I-I p3 10x 9-19-19.tif
# 19  ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2495 10x 190603.tif
# 20         ./dataset/raw_dataset/train/Inflamed/CD62-I-I P1 202026 4X.JPG
# 21         ./dataset/raw_dataset/train/Inflamed/CD41-I-I P0 190830 4x.tif
# 22  ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2501 40x 190603.tif
# 23             ./dataset/raw_dataset/train/Inflamed/CD13-Il-I_QS_2478.tif
# 24        ./dataset/raw_dataset/train/Inflamed/CD41-I-I p3 4x 9-19-19.tif
# 25             ./dataset/raw_dataset/train/Inflamed/CD13-Il-I_QS_2480.tif
# 26         ./dataset/raw_dataset/train/Inflamed/CD42-I-I P5 191002 4X.tif
# 27        ./dataset/raw_dataset/train/Inflamed/CD63-I-I P4 200325 10X.JPG
# 28         ./dataset/raw_dataset/train/Inflamed/CD62-I-I P3 200311 4X.JPG
# 29  ./dataset/raw_dataset/train/Inflamed/CD11 IL-I-QS_2502 40x 190603.tif
# 30         ./dataset/raw_dataset/train/Inflamed/CD63-I-I P4 200325 4X.JPG
# 31        ./dataset/raw_dataset/train/Inflamed/CD63-I-I P2 200313 10X.JPG
# 32             ./dataset/raw_dataset/train/Inflamed/CD13-Il-I_QS_2479.tif
# 33       ./dataset/raw_dataset/train/Inflamed/CD42-I-I P0 190905 10x .tif

# %%
class_ni
# Out:
#            class  \
# 34   NonInflamed
# 35   NonInflamed
# 36   NonInflamed
# 37   NonInflamed
# 38   NonInflamed
# ..           ...
# 280  NonInflamed
# 281  NonInflamed
# 282  NonInflamed
# 283  NonInflamed
# 284  NonInflamed
#
#                                                                       image
# 34     ./dataset/raw_dataset/train/NonInflamed/CD11-LC-NI P12 190905 4x.tif
# 35       ./dataset/raw_dataset/train/NonInflamed/CD24-I-NI P1 190620 4X.tif
# 36      ./dataset/raw_dataset/train/NonInflamed/CD50-I-NI P4 200304 10X.JPG
# 37      ./dataset/raw_dataset/train/NonInflamed/CD27-R-NI P3 190711 10X.tif
# 38   ./dataset/raw_dataset/train/NonInflamed/CD19-LC-NI P6 191002 10X 1.tif
# ..                                                                      ...
# 280    ./dataset/raw_dataset/train/NonInflamed/CD63-LC-NI P4 200316 10X.JPG
# 281     ./dataset/raw_dataset/train/NonInflamed/CD47-LC-NI P2 191017 4x.tif
# 282    ./dataset/raw_dataset/train/NonInflamed/CD26-LC-NI P3 191114 10X.tif
# 283     ./dataset/raw_dataset/train/NonInflamed/CD32-I-NI P0 190722 10X.tif
# 284      ./dataset/raw_dataset/train/NonInflamed/CD28-R-NI P2 190707 4X.tif
#
# [251 rows x 2 columns]

# %%
# Convert parts into NumPy arrays for weight computation
i_numpy = class_i['class'].to_numpy()
ni_numpy = class_ni['class'].to_numpy()

# %%
all_together = np.concatenate((i_numpy, ni_numpy))
unique_classes = np.unique(all_together)

# %%
# weights = class_weight.compute_class_weight('balanced', unique_classes, all_together)
# print(weights)

# %%
class_weights = compute_class_weight(class_weight = "balanced", classes= np.unique(all_together), y = all_together )

# %%
class_weights = dict(enumerate(class_weights))

# %%
class_weights
# Out:
# {0: 4.1911764705882355, 1: 0.5677290836653387}

# %%
df_valid.head(20)
# Out:
#           class  \
# 0      Inflamed
# 1      Inflamed
# 2      Inflamed
# 3      Inflamed
# 4      Inflamed
# 5      Inflamed
# 6      Inflamed
# 7      Inflamed
# 8      Inflamed
# 9   NonInflamed
# 10  NonInflamed
# 11  NonInflamed
# 12  NonInflamed
# 13  NonInflamed
# 14  NonInflamed
# 15  NonInflamed
# 16  NonInflamed
# 17  NonInflamed
# 18  NonInflamed
# 19  NonInflamed
#
#                                                                       image
# 0       ./dataset/raw_dataset/val/Inflamed/CD11 IL-I-QS_2498 20x 190603.tif
# 1             ./dataset/raw_dataset/val/Inflamed/CD62-I-I P1 202026 10X.JPG
# 2            ./dataset/raw_dataset/val/Inflamed/CD41-I-I P2 190909 10x .tif
# 3       ./dataset/raw_dataset/val/Inflamed/CD11 IL-I-QS_2500 40x 190603.tif
# 4              ./dataset/raw_dataset/val/Inflamed/CD63-I-I P3 200318 4X.JPG
# 5       ./dataset/raw_dataset/val/Inflamed/CD11 IL-I-QS_2497 20x 190603.tif
# 6              ./dataset/raw_dataset/val/Inflamed/CD42-I-I P2 190920 4X.tif
# 7             ./dataset/raw_dataset/val/Inflamed/CD62-I-I P2 200304 10X.JPG
# 8       ./dataset/raw_dataset/val/Inflamed/CD11 IL-I-QS_2494 10x 190603.tif
# 9     ./dataset/raw_dataset/val/NonInflamed/CD30-LC-NI P13 191003 10X 1.tif
# 10             ./dataset/raw_dataset/val/NonInflamed/CD13-LC-NI_QS_2482.tif
# 11      ./dataset/raw_dataset/val/NonInflamed/CD62-R-NI P1 10x 02.23.20.JPG
# 12  ./dataset/raw_dataset/val/NonInflamed/CD12 IL-NI-QS_2512 40x 190603.tif
# 13        ./dataset/raw_dataset/val/NonInflamed/CD47-I-NI P0 191007 10X.tif
# 14          ./dataset/raw_dataset/val/NonInflamed/CD32-I p9 10x 9-19-19.tif
# 15        ./dataset/raw_dataset/val/NonInflamed/CD62-R-NI P0 200219 10X.JPG
# 16        ./dataset/raw_dataset/val/NonInflamed/CD30-LC-NI P1 190715 4X.tif
# 17        ./dataset/raw_dataset/val/NonInflamed/CD13-LC-NI P4 190602 4x.tif
# 18        ./dataset/raw_dataset/val/NonInflamed/CD63-LC-NI P3 200309 4X.JPG
# 19        ./dataset/raw_dataset/val/NonInflamed/CD24-RC-NI P4 200526 4X.JPG

# %%
df_test.head(20)
# Out:
#           class  \
# 0      Inflamed
# 1      Inflamed
# 2      Inflamed
# 3      Inflamed
# 4      Inflamed
# 5      Inflamed
# 6   NonInflamed
# 7   NonInflamed
# 8   NonInflamed
# 9   NonInflamed
# 10  NonInflamed
# 11  NonInflamed
# 12  NonInflamed
# 13  NonInflamed
# 14  NonInflamed
# 15  NonInflamed
# 16  NonInflamed
# 17  NonInflamed
# 18  NonInflamed
# 19  NonInflamed
#
#                                                                        image
# 0       ./dataset/raw_dataset/test/Inflamed/CD11 IL-I-QS_2499 20x 190603.tif
# 1                   ./dataset/raw_dataset/test/Inflamed/CD11 ILEUM Inf 3.tif
# 2              ./dataset/raw_dataset/test/Inflamed/CD11-I-I P8 190719 4X.tif
# 3              ./dataset/raw_dataset/test/Inflamed/CD62-I-I P2 200304 4X.JPG
# 4                   ./dataset/raw_dataset/test/Inflamed/CD11 ILEUM Inf 2.tif
# 5       ./dataset/raw_dataset/test/Inflamed/CD11 IL-I-QS_2493 10x 190603.tif
# 6   ./dataset/raw_dataset/test/NonInflamed/CD12 IL-NI-QS_2505 20x 190603.tif
# 7          ./dataset/raw_dataset/test/NonInflamed/CD50-R-NI P0 191119 4X.tif
# 8        ./dataset/raw_dataset/test/NonInflamed/CD62-R-NI P1 5x 02.23.20.JPG
# 9      ./dataset/raw_dataset/test/NonInflamed/CD60-LC-NI P0 10x 01.17.19.JPG
# 10       ./dataset/raw_dataset/test/NonInflamed/CD19-LC-NI P0 190524 10x.tif
# 11       ./dataset/raw_dataset/test/NonInflamed/CD22-LC-NI P2 190708 4x .tif
# 12         ./dataset/raw_dataset/test/NonInflamed/CD62-R-NI P4 200313 4X.JPG
# 13     ./dataset/raw_dataset/test/NonInflamed/CD19-LC-NI P6 191002 20X 3.tif
# 14           ./dataset/raw_dataset/test/NonInflamed/CD26-LC P5 191201 4x.tif
# 15        ./dataset/raw_dataset/test/NonInflamed/CD23-LC-NI P3 190724 4X.tif
# 16        ./dataset/raw_dataset/test/NonInflamed/CD19-LC-NI P1 190529 4x.tif
# 17       ./dataset/raw_dataset/test/NonInflamed/CD48-RC-NI P5 200526 10X.JPG
# 18        ./dataset/raw_dataset/test/NonInflamed/CD24-I-NI P1 190618 10X.tif
# 19       ./dataset/raw_dataset/test/NonInflamed/CD20-LC-NI P2 190617 10X.tif

# %%
plt.figure(figsize=(6,4))

ax = sns.countplot(x='class', data=df_train, palette="mako")

plt.xlabel("Class", fontsize= 12)
plt.ylabel("No of Samples", fontsize= 12)
plt.ylim(0,800)
plt.xticks([0,1], ['Inflamed', 'NonInflamed'], fontsize = 11)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.30, p.get_height()+300), fontsize = 13)
    
plt.show()

# %%
plt.figure(figsize=(7,5))

df_train['class'].value_counts().plot(kind='pie',labels = ['',''], autopct='%1.1f%%', colors = ['darkcyan','blue'], explode = [0,0.05], textprops = {"fontsize":15})

plt.legend(labels=['Inflamed', 'NonInflamed'])
plt.show()

# %%
plt.figure(figsize=(6,4))

ax = sns.countplot(x='class', data=df_test, palette="mako")

plt.xlabel("Class", fontsize= 12)
plt.ylabel("No of Samples", fontsize= 12)
plt.ylim(0,200)
plt.xticks([0,1], ['Inflamed', 'NonInflamed'], fontsize = 11)

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.32, p.get_height()+20), fontsize = 13)
    
plt.show()

# %%
plt.figure(figsize=(7,5))

df_test['class'].value_counts().plot(kind='pie',labels = ['',''], autopct='%1.1f%%', colors = ['darkcyan','blue'], explode = [0,0.05], textprops = {"fontsize":15})

plt.legend(labels=['Inflamed', 'NonInflamed'])
plt.show()

# %%
print('Train Set - Inflamed')

plt.figure(figsize=(12,12))

for i in range(0, 12):
    plt.subplot(3,4,i + 1)
    img = cv2.imread(train_i[i])
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()

plt.show()
# Out:
# Train Set - Inflamed

# %%
print('Train Set - NonInflamed')

plt.figure(figsize=(12,12))

for i in range(0, 12):
    plt.subplot(3,4,i + 1)
    img = cv2.imread(train_ni[i])
    img = cv2.resize(img, (IMG_SIZE,IMG_SIZE))
    plt.imshow(img)
    plt.axis("off")

plt.tight_layout()

plt.show()
# Out:
# Train Set - NonInflamed

# %%
train_datagen = ImageDataGenerator(rescale=1/255.)
# train_datagen = ImageDataGenerator(
#         rescale=1/255.,
#         rotation_range=10, # rotation
#         width_shift_range=0.2, # horizontal shift
#         height_shift_range=0.2, # vertical shift
#         zoom_range=0.2, # zoom
#         horizontal_flip=True, # horizontal flip
#         vertical_flip= True,
#         fill_mode = 'reflect',
#         brightness_range=[0.2,1.2])

valid_datagen = ImageDataGenerator(rescale=1/255.)

test_datagen = ImageDataGenerator(rescale = 1/255.)

# %%
ds_train = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (IMG_SIZE, IMG_SIZE),
                                                 batch_size = BATCH,
                                                 class_mode = 'binary',
                                                 shuffle=True,
                                                 classes={'Inflamed': 0., 'NonInflamed': 1.}
                                                 )
# Out:
# Found 285 images belonging to 2 classes.

# %%
ds_valid = valid_datagen.flow_from_directory(valid_dir,
                                                 target_size = (IMG_SIZE, IMG_SIZE),
                                                 batch_size = BATCH,
                                                 class_mode = 'binary',
                                                 shuffle=True,
                                                 classes={'Inflamed': 0., 'NonInflamed': 1.}
                                                 )
# Out:
# Found 80 images belonging to 2 classes.

# %%
ds_test = test_datagen.flow_from_directory(test_dir ,
                                            target_size = (IMG_SIZE, IMG_SIZE),
                                            batch_size = 1,
                                            class_mode = 'binary',
                                            shuffle=False,
                                            classes={'Inflamed': 0., 'NonInflamed': 1.}
                                            )
# Out:
# Found 43 images belonging to 2 classes.

# %%
# Get few samples for both the classes
inflamed_samples = (df_train[df_train['class']=='Inflamed']['image'].iloc[:5]).tolist()
noninflamed_samples = (df_train[df_train['class']=='NonInflamed']['image'].iloc[:5]).tolist()

# Concat the data in a single list and del the above two list
samples = inflamed_samples + noninflamed_samples
del inflamed_samples, noninflamed_samples

# Plot the data 
f, ax = plt.subplots(2,5, figsize=(20,6))
for i in range(10):
    img = imread(samples[i])
    ax[i//5, i%5].imshow(img)
    if i<5:
        ax[i//5, i%5].set_title("Inflamed")
    else:
        ax[i//5, i%5].set_title("NonInflamed")
    ax[i//5, i%5].axis('off')
    ax[i//5, i%5].set_aspect('auto')
plt.show()

# %%
checkpoint_path = "./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
checkpoint = keras.callbacks.ModelCheckpoint('./checkpoint_path/final_cnn_transfer/training_3/model{epoch:08d}.h5',save_freq='epoch', period=10)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
#Setting callbakcs

# early_stopping = callbacks.EarlyStopping(
#     monitor='val_loss',
#     patience=5,
#     min_delta=1e-7,
#     restore_best_weights=True,
# )

# plateau = callbacks.ReduceLROnPlateau(
#     monitor='val_loss',
#     factor = 0.2,                                     
#     patience = 2,                                   
#     min_delt = 1e-7,                                
#     cooldown = 0,                               
#     verbose = 1
# )

# %%
base_model = tf.keras.applications.ResNet152V2(
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False)

base_model.trainable = False

def get_pretrained():
    
    #Input shape = [width, height, color channels]
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    x = base_model(inputs)

    # Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.1)(x)
    
    #Final Layer (Output)
    output = layers.Dense(1, activation='sigmoid')(x)
    
    model = keras.Model(inputs=[inputs], outputs=output)
    
    return model

# %%
# focal loss 
def focal_loss(alpha=0.25,gamma=2.0):
    def focal_crossentropy(y_true, y_pred):
        bce = K.binary_crossentropy(y_true, y_pred)
        
        y_pred = K.clip(y_pred, K.epsilon(), 1.- K.epsilon())
        p_t = (y_true*y_pred) + ((1-y_true)*(1-y_pred))
        
        alpha_factor = 1
        modulating_factor = 1

        alpha_factor = y_true*alpha + ((1-alpha)*(1-y_true))
        modulating_factor = K.pow((1-p_t), gamma)

        # compute the final loss and return
        return K.mean(alpha_factor*modulating_factor*bce, axis=-1)
    return focal_crossentropy

# %%
keras.backend.clear_session()

model_pretrained = get_pretrained()
optimizer = RMSprop(0.0001)
model_pretrained.compile(loss=focal_loss()
              , optimizer = optimizer, metrics='binary_accuracy')

model_pretrained.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet152v2 (Model)          (None, 7, 7, 2048)        58331648
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 58,594,049
# Trainable params: 262,401
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
history = model_pretrained.fit(ds_train,
          batch_size = BATCH, epochs = 100,
          validation_data=ds_valid,
        #   callbacks=[early_stopping, plateau, cp_callback, checkpoint],
          callbacks=[cp_callback, checkpoint],
          class_weight = class_weights,
          steps_per_epoch=(len(df_train)/BATCH),
          validation_steps=(len(df_valid)/BATCH));
# Out:
# Epoch 1/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0855 - binary_accuracy: 0.3298
# Epoch 00001: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 20s 2s/step - loss: 0.0855 - binary_accuracy: 0.3298 - val_loss: 0.0836 - val_binary_accuracy: 0.5333
# Epoch 2/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0907 - binary_accuracy: 0.3649
# Epoch 00002: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0907 - binary_accuracy: 0.3649 - val_loss: 0.0971 - val_binary_accuracy: 0.3500
# Epoch 3/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0816 - binary_accuracy: 0.4035
# Epoch 00003: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0816 - binary_accuracy: 0.4035 - val_loss: 0.1015 - val_binary_accuracy: 0.3500
# Epoch 4/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0635 - binary_accuracy: 0.3474
# Epoch 00004: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 19s 2s/step - loss: 0.0635 - binary_accuracy: 0.3474 - val_loss: 0.0806 - val_binary_accuracy: 0.4333
# Epoch 5/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0670 - binary_accuracy: 0.4421
# Epoch 00005: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0670 - binary_accuracy: 0.4421 - val_loss: 0.0810 - val_binary_accuracy: 0.4333
# Epoch 6/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0582 - binary_accuracy: 0.4982
# Epoch 00006: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0582 - binary_accuracy: 0.4982 - val_loss: 0.0800 - val_binary_accuracy: 0.4333
# Epoch 7/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0595 - binary_accuracy: 0.4561
# Epoch 00007: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0595 - binary_accuracy: 0.4561 - val_loss: 0.0740 - val_binary_accuracy: 0.4333
# Epoch 8/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0495 - binary_accuracy: 0.5439
# Epoch 00008: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0495 - binary_accuracy: 0.5439 - val_loss: 0.0627 - val_binary_accuracy: 0.5667
# Epoch 9/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0587 - binary_accuracy: 0.5754
# Epoch 00009: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0587 - binary_accuracy: 0.5754 - val_loss: 0.0745 - val_binary_accuracy: 0.3833
# Epoch 10/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0544 - binary_accuracy: 0.4842
# Epoch 00010: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0544 - binary_accuracy: 0.4842 - val_loss: 0.0619 - val_binary_accuracy: 0.4833
# Epoch 11/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0589 - binary_accuracy: 0.5193
# Epoch 00011: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0589 - binary_accuracy: 0.5193 - val_loss: 0.0765 - val_binary_accuracy: 0.4000
# Epoch 12/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0644 - binary_accuracy: 0.4702
# Epoch 00012: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0644 - binary_accuracy: 0.4702 - val_loss: 0.0843 - val_binary_accuracy: 0.3667
# Epoch 13/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0508 - binary_accuracy: 0.5158
# Epoch 00013: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0508 - binary_accuracy: 0.5158 - val_loss: 0.0662 - val_binary_accuracy: 0.4500
# Epoch 14/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0462 - binary_accuracy: 0.5860
# Epoch 00014: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 19s 2s/step - loss: 0.0462 - binary_accuracy: 0.5860 - val_loss: 0.0691 - val_binary_accuracy: 0.4333
# Epoch 15/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0503 - binary_accuracy: 0.6175
# Epoch 00015: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0503 - binary_accuracy: 0.6175 - val_loss: 0.0649 - val_binary_accuracy: 0.4333
# Epoch 16/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0525 - binary_accuracy: 0.6351
# Epoch 00016: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0525 - binary_accuracy: 0.6351 - val_loss: 0.0739 - val_binary_accuracy: 0.4000
# Epoch 17/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0565 - binary_accuracy: 0.5544
# Epoch 00017: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0565 - binary_accuracy: 0.5544 - val_loss: 0.0759 - val_binary_accuracy: 0.4000
# Epoch 18/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0508 - binary_accuracy: 0.6000
# Epoch 00018: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0508 - binary_accuracy: 0.6000 - val_loss: 0.0770 - val_binary_accuracy: 0.4000
# Epoch 19/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0512 - binary_accuracy: 0.5544
# Epoch 00019: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0512 - binary_accuracy: 0.5544 - val_loss: 0.0636 - val_binary_accuracy: 0.4667
# Epoch 20/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0459 - binary_accuracy: 0.6526
# Epoch 00020: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0459 - binary_accuracy: 0.6526 - val_loss: 0.0658 - val_binary_accuracy: 0.4667
# Epoch 21/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0478 - binary_accuracy: 0.5930
# Epoch 00021: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0478 - binary_accuracy: 0.5930 - val_loss: 0.0649 - val_binary_accuracy: 0.5000
# Epoch 22/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0476 - binary_accuracy: 0.6281
# Epoch 00022: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0476 - binary_accuracy: 0.6281 - val_loss: 0.0630 - val_binary_accuracy: 0.4667
# Epoch 23/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0439 - binary_accuracy: 0.6632
# Epoch 00023: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0439 - binary_accuracy: 0.6632 - val_loss: 0.0653 - val_binary_accuracy: 0.4833
# Epoch 24/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0454 - binary_accuracy: 0.6035
# Epoch 00024: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0454 - binary_accuracy: 0.6035 - val_loss: 0.0574 - val_binary_accuracy: 0.5333
# Epoch 25/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0425 - binary_accuracy: 0.6421
# Epoch 00025: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0425 - binary_accuracy: 0.6421 - val_loss: 0.0549 - val_binary_accuracy: 0.5667
# Epoch 26/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0433 - binary_accuracy: 0.7228
# Epoch 00026: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0433 - binary_accuracy: 0.7228 - val_loss: 0.0596 - val_binary_accuracy: 0.5167
# Epoch 27/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0384 - binary_accuracy: 0.7088
# Epoch 00027: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0384 - binary_accuracy: 0.7088 - val_loss: 0.0543 - val_binary_accuracy: 0.6167
# Epoch 28/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0491 - binary_accuracy: 0.6807
# Epoch 00028: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0491 - binary_accuracy: 0.6807 - val_loss: 0.0654 - val_binary_accuracy: 0.5167
# Epoch 29/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0450 - binary_accuracy: 0.6281
# Epoch 00029: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0450 - binary_accuracy: 0.6281 - val_loss: 0.0646 - val_binary_accuracy: 0.5000
# Epoch 30/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0394 - binary_accuracy: 0.6632
# Epoch 00030: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0394 - binary_accuracy: 0.6632 - val_loss: 0.0542 - val_binary_accuracy: 0.5833
# Epoch 31/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0390 - binary_accuracy: 0.6667
# Epoch 00031: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0390 - binary_accuracy: 0.6667 - val_loss: 0.0500 - val_binary_accuracy: 0.6000
# Epoch 32/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0395 - binary_accuracy: 0.7088
# Epoch 00032: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0395 - binary_accuracy: 0.7088 - val_loss: 0.0506 - val_binary_accuracy: 0.6167
# Epoch 33/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0476 - binary_accuracy: 0.6842
# Epoch 00033: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0476 - binary_accuracy: 0.6842 - val_loss: 0.0587 - val_binary_accuracy: 0.5333
# Epoch 34/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0405 - binary_accuracy: 0.6667
# Epoch 00034: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0405 - binary_accuracy: 0.6667 - val_loss: 0.0521 - val_binary_accuracy: 0.5833
# Epoch 35/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0362 - binary_accuracy: 0.7404
# Epoch 00035: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0362 - binary_accuracy: 0.7404 - val_loss: 0.0550 - val_binary_accuracy: 0.5500
# Epoch 36/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0392 - binary_accuracy: 0.7123
# Epoch 00036: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0392 - binary_accuracy: 0.7123 - val_loss: 0.0585 - val_binary_accuracy: 0.5000
# Epoch 37/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0389 - binary_accuracy: 0.7158
# Epoch 00037: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0389 - binary_accuracy: 0.7158 - val_loss: 0.0632 - val_binary_accuracy: 0.5500
# Epoch 38/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0437 - binary_accuracy: 0.7088
# Epoch 00038: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0437 - binary_accuracy: 0.7088 - val_loss: 0.0582 - val_binary_accuracy: 0.5167
# Epoch 39/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0380 - binary_accuracy: 0.6842
# Epoch 00039: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0380 - binary_accuracy: 0.6842 - val_loss: 0.0502 - val_binary_accuracy: 0.7000
# Epoch 40/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0381 - binary_accuracy: 0.7719
# Epoch 00040: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0381 - binary_accuracy: 0.7719 - val_loss: 0.0574 - val_binary_accuracy: 0.6167
# Epoch 41/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0375 - binary_accuracy: 0.7333
# Epoch 00041: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0375 - binary_accuracy: 0.7333 - val_loss: 0.0487 - val_binary_accuracy: 0.6333
# Epoch 42/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0359 - binary_accuracy: 0.7930
# Epoch 00042: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0359 - binary_accuracy: 0.7930 - val_loss: 0.0538 - val_binary_accuracy: 0.6667
# Epoch 43/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0393 - binary_accuracy: 0.6772
# Epoch 00043: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0393 - binary_accuracy: 0.6772 - val_loss: 0.0558 - val_binary_accuracy: 0.6333
# Epoch 44/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0382 - binary_accuracy: 0.7018
# Epoch 00044: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0382 - binary_accuracy: 0.7018 - val_loss: 0.0545 - val_binary_accuracy: 0.6167
# Epoch 45/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0324 - binary_accuracy: 0.7719
# Epoch 00045: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0324 - binary_accuracy: 0.7719 - val_loss: 0.0544 - val_binary_accuracy: 0.6000
# Epoch 46/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0362 - binary_accuracy: 0.7579
# Epoch 00046: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0362 - binary_accuracy: 0.7579 - val_loss: 0.0537 - val_binary_accuracy: 0.6000
# Epoch 47/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0487 - binary_accuracy: 0.7228
# Epoch 00047: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0487 - binary_accuracy: 0.7228 - val_loss: 0.0565 - val_binary_accuracy: 0.5833
# Epoch 48/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0367 - binary_accuracy: 0.7333
# Epoch 00048: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0367 - binary_accuracy: 0.7333 - val_loss: 0.0608 - val_binary_accuracy: 0.5333
# Epoch 49/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0295 - binary_accuracy: 0.7368
# Epoch 00049: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0295 - binary_accuracy: 0.7368 - val_loss: 0.0483 - val_binary_accuracy: 0.7000
# Epoch 50/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0370 - binary_accuracy: 0.8000
# Epoch 00050: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0370 - binary_accuracy: 0.8000 - val_loss: 0.0601 - val_binary_accuracy: 0.5167
# Epoch 51/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0355 - binary_accuracy: 0.7474
# Epoch 00051: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0355 - binary_accuracy: 0.7474 - val_loss: 0.0558 - val_binary_accuracy: 0.5833
# Epoch 52/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0335 - binary_accuracy: 0.7298
# Epoch 00052: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0335 - binary_accuracy: 0.7298 - val_loss: 0.0505 - val_binary_accuracy: 0.6500
# Epoch 53/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0370 - binary_accuracy: 0.7719
# Epoch 00053: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0370 - binary_accuracy: 0.7719 - val_loss: 0.0634 - val_binary_accuracy: 0.5167
# Epoch 54/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0343 - binary_accuracy: 0.6982
# Epoch 00054: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0343 - binary_accuracy: 0.6982 - val_loss: 0.0486 - val_binary_accuracy: 0.7333
# Epoch 55/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0366 - binary_accuracy: 0.7123
# Epoch 00055: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0366 - binary_accuracy: 0.7123 - val_loss: 0.0544 - val_binary_accuracy: 0.6333
# Epoch 56/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0397 - binary_accuracy: 0.7333
# Epoch 00056: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0397 - binary_accuracy: 0.7333 - val_loss: 0.0611 - val_binary_accuracy: 0.5667
# Epoch 57/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0304 - binary_accuracy: 0.7123
# Epoch 00057: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0304 - binary_accuracy: 0.7123 - val_loss: 0.0554 - val_binary_accuracy: 0.6333
# Epoch 58/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0294 - binary_accuracy: 0.7825
# Epoch 00058: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0294 - binary_accuracy: 0.7825 - val_loss: 0.0521 - val_binary_accuracy: 0.7167
# Epoch 59/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0308 - binary_accuracy: 0.7474
# Epoch 00059: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0308 - binary_accuracy: 0.7474 - val_loss: 0.0519 - val_binary_accuracy: 0.6833
# Epoch 60/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0349 - binary_accuracy: 0.7509
# Epoch 00060: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0349 - binary_accuracy: 0.7509 - val_loss: 0.0558 - val_binary_accuracy: 0.6333
# Epoch 61/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0345 - binary_accuracy: 0.7754
# Epoch 00061: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0345 - binary_accuracy: 0.7754 - val_loss: 0.0576 - val_binary_accuracy: 0.6000
# Epoch 62/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0328 - binary_accuracy: 0.7544
# Epoch 00062: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0328 - binary_accuracy: 0.7544 - val_loss: 0.0603 - val_binary_accuracy: 0.6167
# Epoch 63/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0354 - binary_accuracy: 0.7684
# Epoch 00063: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0354 - binary_accuracy: 0.7684 - val_loss: 0.0545 - val_binary_accuracy: 0.6667
# Epoch 64/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0325 - binary_accuracy: 0.7544
# Epoch 00064: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0325 - binary_accuracy: 0.7544 - val_loss: 0.0589 - val_binary_accuracy: 0.5833
# Epoch 65/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0394 - binary_accuracy: 0.7754
# Epoch 00065: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0394 - binary_accuracy: 0.7754 - val_loss: 0.0609 - val_binary_accuracy: 0.6000
# Epoch 66/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0328 - binary_accuracy: 0.7263
# Epoch 00066: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0328 - binary_accuracy: 0.7263 - val_loss: 0.0539 - val_binary_accuracy: 0.7000
# Epoch 67/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0313 - binary_accuracy: 0.8140
# Epoch 00067: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0313 - binary_accuracy: 0.8140 - val_loss: 0.0590 - val_binary_accuracy: 0.6167
# Epoch 68/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0317 - binary_accuracy: 0.7158
# Epoch 00068: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0317 - binary_accuracy: 0.7158 - val_loss: 0.0546 - val_binary_accuracy: 0.6833
# Epoch 69/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0248 - binary_accuracy: 0.8211
# Epoch 00069: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0248 - binary_accuracy: 0.8211 - val_loss: 0.0526 - val_binary_accuracy: 0.7333
# Epoch 70/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0391 - binary_accuracy: 0.7544
# Epoch 00070: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0391 - binary_accuracy: 0.7544 - val_loss: 0.0605 - val_binary_accuracy: 0.5833
# Epoch 71/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0262 - binary_accuracy: 0.7789
# Epoch 00071: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0262 - binary_accuracy: 0.7789 - val_loss: 0.0516 - val_binary_accuracy: 0.7000
# Epoch 72/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0298 - binary_accuracy: 0.8140
# Epoch 00072: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0298 - binary_accuracy: 0.8140 - val_loss: 0.0547 - val_binary_accuracy: 0.6500
# Epoch 73/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0262 - binary_accuracy: 0.8105
# Epoch 00073: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0262 - binary_accuracy: 0.8105 - val_loss: 0.0524 - val_binary_accuracy: 0.7000
# Epoch 74/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0301 - binary_accuracy: 0.8000
# Epoch 00074: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0301 - binary_accuracy: 0.8000 - val_loss: 0.0542 - val_binary_accuracy: 0.6333
# Epoch 75/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0319 - binary_accuracy: 0.7544
# Epoch 00075: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0319 - binary_accuracy: 0.7544 - val_loss: 0.0555 - val_binary_accuracy: 0.6167
# Epoch 76/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0267 - binary_accuracy: 0.8000
# Epoch 00076: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0267 - binary_accuracy: 0.8000 - val_loss: 0.0545 - val_binary_accuracy: 0.6167
# Epoch 77/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0251 - binary_accuracy: 0.7825
# Epoch 00077: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0251 - binary_accuracy: 0.7825 - val_loss: 0.0491 - val_binary_accuracy: 0.7167
# Epoch 78/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0355 - binary_accuracy: 0.7789
# Epoch 00078: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0355 - binary_accuracy: 0.7789 - val_loss: 0.0526 - val_binary_accuracy: 0.6500
# Epoch 79/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0275 - binary_accuracy: 0.8175
# Epoch 00079: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0275 - binary_accuracy: 0.8175 - val_loss: 0.0550 - val_binary_accuracy: 0.6667
# Epoch 80/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0361 - binary_accuracy: 0.8140
# Epoch 00080: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0361 - binary_accuracy: 0.8140 - val_loss: 0.0621 - val_binary_accuracy: 0.5667
# Epoch 81/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0324 - binary_accuracy: 0.7649
# Epoch 00081: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0324 - binary_accuracy: 0.7649 - val_loss: 0.0565 - val_binary_accuracy: 0.6167
# Epoch 82/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0246 - binary_accuracy: 0.7895
# Epoch 00082: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0246 - binary_accuracy: 0.7895 - val_loss: 0.0549 - val_binary_accuracy: 0.7000
# Epoch 83/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0306 - binary_accuracy: 0.7789
# Epoch 00083: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0306 - binary_accuracy: 0.7789 - val_loss: 0.0533 - val_binary_accuracy: 0.7333
# Epoch 84/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0285 - binary_accuracy: 0.8211
# Epoch 00084: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0285 - binary_accuracy: 0.8211 - val_loss: 0.0574 - val_binary_accuracy: 0.6500
# Epoch 85/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0320 - binary_accuracy: 0.8070
# Epoch 00085: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0320 - binary_accuracy: 0.8070 - val_loss: 0.0607 - val_binary_accuracy: 0.6000
# Epoch 86/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0336 - binary_accuracy: 0.7439
# Epoch 00086: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0336 - binary_accuracy: 0.7439 - val_loss: 0.0572 - val_binary_accuracy: 0.6667
# Epoch 87/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0324 - binary_accuracy: 0.8105
# Epoch 00087: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0324 - binary_accuracy: 0.8105 - val_loss: 0.0537 - val_binary_accuracy: 0.6333
# Epoch 88/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0294 - binary_accuracy: 0.7789
# Epoch 00088: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0294 - binary_accuracy: 0.7789 - val_loss: 0.0529 - val_binary_accuracy: 0.6333
# Epoch 89/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0358 - binary_accuracy: 0.7368
# Epoch 00089: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0358 - binary_accuracy: 0.7368 - val_loss: 0.0508 - val_binary_accuracy: 0.6833
# Epoch 90/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0266 - binary_accuracy: 0.8211
# Epoch 00090: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 16s 2s/step - loss: 0.0266 - binary_accuracy: 0.8211 - val_loss: 0.0528 - val_binary_accuracy: 0.6667
# Epoch 91/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0254 - binary_accuracy: 0.8246
# Epoch 00091: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0254 - binary_accuracy: 0.8246 - val_loss: 0.0518 - val_binary_accuracy: 0.6833
# Epoch 92/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0324 - binary_accuracy: 0.7860
# Epoch 00092: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0324 - binary_accuracy: 0.7860 - val_loss: 0.0512 - val_binary_accuracy: 0.7167
# Epoch 93/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0286 - binary_accuracy: 0.7614
# Epoch 00093: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0286 - binary_accuracy: 0.7614 - val_loss: 0.0498 - val_binary_accuracy: 0.7667
# Epoch 94/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0270 - binary_accuracy: 0.8456
# Epoch 00094: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0270 - binary_accuracy: 0.8456 - val_loss: 0.0547 - val_binary_accuracy: 0.7000
# Epoch 95/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0283 - binary_accuracy: 0.8070
# Epoch 00095: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 18s 2s/step - loss: 0.0283 - binary_accuracy: 0.8070 - val_loss: 0.0531 - val_binary_accuracy: 0.7500
# Epoch 96/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0267 - binary_accuracy: 0.8421
# Epoch 00096: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0267 - binary_accuracy: 0.8421 - val_loss: 0.0539 - val_binary_accuracy: 0.7167
# Epoch 97/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0244 - binary_accuracy: 0.8035
# Epoch 00097: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0244 - binary_accuracy: 0.8035 - val_loss: 0.0528 - val_binary_accuracy: 0.7500
# Epoch 98/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0222 - binary_accuracy: 0.8351
# Epoch 00098: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0222 - binary_accuracy: 0.8351 - val_loss: 0.0534 - val_binary_accuracy: 0.7333
# Epoch 99/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0290 - binary_accuracy: 0.8246
# Epoch 00099: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0290 - binary_accuracy: 0.8246 - val_loss: 0.0527 - val_binary_accuracy: 0.7167
# Epoch 100/100
# 9/8 [==============================] - ETA: 0s - loss: 0.0232 - binary_accuracy: 0.8386
# Epoch 00100: saving model to ./checkpoint_path/final_cnn_transfer/cp.ckpt
# 9/8 [==============================] - 17s 2s/step - loss: 0.0232 - binary_accuracy: 0.8386 - val_loss: 0.0527 - val_binary_accuracy: 0.7333

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['binary_accuracy']
    val_acc = history.history['val_binary_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy-%')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
plot_learning_curve(history)

# %%
score = model_pretrained.evaluate(ds_test, steps = len(df_test), verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.03468078374862671
# Test accuracy: 0.8730158805847168

# %%
num_label = {'Inflamed': 0, 'NonInflamed' : 1}
Y_test = df_test['class'].copy().map(num_label).astype('int')

# %%
ds_test.reset()
predictions = model_pretrained.predict(ds_test, steps=len(ds_test), verbose=0)
pred_labels= np.where(predictions>0.5, 1, 0)

# %%
print("Test Accuracy: ", accuracy_score(Y_test, pred_labels))
# Out:
# Test Accuracy:  0.873015873015873

# %%
confusion_matrix = metrics.confusion_matrix(Y_test, pred_labels)
sns.heatmap(confusion_matrix, annot=True, fmt="d")

plt.xlabel("Predicted Label", fontsize= 12)
plt.ylabel("True Label", fontsize= 12)

plt.show()

# %%
print(metrics.classification_report(Y_test, pred_labels, labels = [0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         8
#            1       0.93      0.93      0.93        55
#
#     accuracy                           0.87        63
#    macro avg       0.71      0.71      0.71        63
# weighted avg       0.87      0.87      0.87        63

# %%
roc_auc = metrics.roc_auc_score(Y_test, predictions)
print('ROC_AUC: ', roc_auc)

fpr, tpr, thresholds = metrics.roc_curve(Y_test, predictions)

plt.plot(fpr, tpr, label = 'ROC_AUC = %0.3f' % roc_auc)

plt.xlabel("False Positive Rate", fontsize= 12)
plt.ylabel("True Positive Rate", fontsize= 12)
plt.legend(loc="lower right")

plt.show()
# Out:
# ROC_AUC:  0.8613636363636363

# %% [markdown]
# # Training 2

# %%
tf.keras.backend.clear_session()

# %%
base_model = tf.keras.applications.ResNet152V2(
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False)

base_model.trainable = False

def get_pretrained():
    
    #Input shape = [width, height, color channels]
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    x = base_model(inputs)

    # Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.1)(x)
    
    #Final Layer (Output)
    output = layers.Dense(1, activation='sigmoid')(x)
    
    model = keras.Model(inputs=[inputs], outputs=output)
    
    return model

# %%
keras.backend.clear_session()

model_pretrained = get_pretrained()
model_pretrained.compile(loss='binary_crossentropy'
            , optimizer = keras.optimizers.Adam(learning_rate=5e-5), metrics='binary_accuracy')

model_pretrained.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet152v2 (Model)          (None, 7, 7, 2048)        58331648
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 58,594,049
# Trainable params: 262,401
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
history = model_pretrained.fit(ds_train,
          batch_size = BATCH, epochs = 100,
          validation_data=ds_valid,
          callbacks=[cp_callback, checkpoint],
          class_weight = class_weights,
          steps_per_epoch=(len(df_train)/BATCH),
          validation_steps=(len(df_valid)/BATCH));
# Out:
# Epoch 1/100
# 5/4 [=================================] - ETA: -1s - loss: 0.7261 - binary_accuracy: 0.7088
# Epoch 00001: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.7261 - binary_accuracy: 0.7088 - val_loss: 0.6405 - val_binary_accuracy: 0.6500
# Epoch 2/100
# 5/4 [=================================] - ETA: -1s - loss: 0.7066 - binary_accuracy: 0.6386
# Epoch 00002: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.7066 - binary_accuracy: 0.6386 - val_loss: 0.6595 - val_binary_accuracy: 0.5667
# Epoch 3/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6960 - binary_accuracy: 0.6456
# Epoch 00003: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.6960 - binary_accuracy: 0.6456 - val_loss: 0.6608 - val_binary_accuracy: 0.6167
# Epoch 4/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6919 - binary_accuracy: 0.6702
# Epoch 00004: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.6919 - binary_accuracy: 0.6702 - val_loss: 0.6757 - val_binary_accuracy: 0.6000
# Epoch 5/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6607 - binary_accuracy: 0.6596
# Epoch 00005: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.6607 - binary_accuracy: 0.6596 - val_loss: 0.6892 - val_binary_accuracy: 0.5833
# Epoch 6/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6322 - binary_accuracy: 0.6386
# Epoch 00006: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 21s 4s/step - loss: 0.6322 - binary_accuracy: 0.6386 - val_loss: 0.6947 - val_binary_accuracy: 0.5833
# Epoch 7/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6388 - binary_accuracy: 0.6281
# Epoch 00007: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.6388 - binary_accuracy: 0.6281 - val_loss: 0.6928 - val_binary_accuracy: 0.6000
# Epoch 8/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6074 - binary_accuracy: 0.6702
# Epoch 00008: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.6074 - binary_accuracy: 0.6702 - val_loss: 0.6927 - val_binary_accuracy: 0.6000
# Epoch 9/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5982 - binary_accuracy: 0.6877
# Epoch 00009: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.5982 - binary_accuracy: 0.6877 - val_loss: 0.6711 - val_binary_accuracy: 0.6167
# Epoch 10/100
# 5/4 [=================================] - ETA: -1s - loss: 0.6098 - binary_accuracy: 0.7088
# Epoch 00010: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.6098 - binary_accuracy: 0.7088 - val_loss: 0.6545 - val_binary_accuracy: 0.6667
# Epoch 11/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5790 - binary_accuracy: 0.7649
# Epoch 00011: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.5790 - binary_accuracy: 0.7649 - val_loss: 0.6502 - val_binary_accuracy: 0.6667
# Epoch 12/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5979 - binary_accuracy: 0.7298
# Epoch 00012: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.5979 - binary_accuracy: 0.7298 - val_loss: 0.6434 - val_binary_accuracy: 0.6833
# Epoch 13/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5839 - binary_accuracy: 0.7474
# Epoch 00013: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5839 - binary_accuracy: 0.7474 - val_loss: 0.6562 - val_binary_accuracy: 0.6833
# Epoch 14/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5701 - binary_accuracy: 0.7474
# Epoch 00014: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5701 - binary_accuracy: 0.7474 - val_loss: 0.6485 - val_binary_accuracy: 0.6833
# Epoch 15/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5510 - binary_accuracy: 0.7789
# Epoch 00015: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.5510 - binary_accuracy: 0.7789 - val_loss: 0.6391 - val_binary_accuracy: 0.7000
# Epoch 16/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5470 - binary_accuracy: 0.7719
# Epoch 00016: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5470 - binary_accuracy: 0.7719 - val_loss: 0.6420 - val_binary_accuracy: 0.7000
# Epoch 17/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5344 - binary_accuracy: 0.7404
# Epoch 00017: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5344 - binary_accuracy: 0.7404 - val_loss: 0.6506 - val_binary_accuracy: 0.6833
# Epoch 18/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5376 - binary_accuracy: 0.7404
# Epoch 00018: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5376 - binary_accuracy: 0.7404 - val_loss: 0.6389 - val_binary_accuracy: 0.7167
# Epoch 19/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5455 - binary_accuracy: 0.7614
# Epoch 00019: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5455 - binary_accuracy: 0.7614 - val_loss: 0.6267 - val_binary_accuracy: 0.7167
# Epoch 20/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5493 - binary_accuracy: 0.7825
# Epoch 00020: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5493 - binary_accuracy: 0.7825 - val_loss: 0.6159 - val_binary_accuracy: 0.7167
# Epoch 21/100
# 5/4 [=================================] - ETA: 0s - loss: 0.5091 - binary_accuracy: 0.7895
# Epoch 00021: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5091 - binary_accuracy: 0.7895 - val_loss: 0.6124 - val_binary_accuracy: 0.7167
# Epoch 22/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5174 - binary_accuracy: 0.8035
# Epoch 00022: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5174 - binary_accuracy: 0.8035 - val_loss: 0.6168 - val_binary_accuracy: 0.7167
# Epoch 23/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5030 - binary_accuracy: 0.8000
# Epoch 00023: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5030 - binary_accuracy: 0.8000 - val_loss: 0.6143 - val_binary_accuracy: 0.7167
# Epoch 24/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5655 - binary_accuracy: 0.7789
# Epoch 00024: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5655 - binary_accuracy: 0.7789 - val_loss: 0.6254 - val_binary_accuracy: 0.7000
# Epoch 25/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5050 - binary_accuracy: 0.7930
# Epoch 00025: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5050 - binary_accuracy: 0.7930 - val_loss: 0.6230 - val_binary_accuracy: 0.7000
# Epoch 26/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5210 - binary_accuracy: 0.7509
# Epoch 00026: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.5210 - binary_accuracy: 0.7509 - val_loss: 0.6163 - val_binary_accuracy: 0.7000
# Epoch 27/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5148 - binary_accuracy: 0.8211
# Epoch 00027: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5148 - binary_accuracy: 0.8211 - val_loss: 0.6065 - val_binary_accuracy: 0.7167
# Epoch 28/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5274 - binary_accuracy: 0.8000
# Epoch 00028: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.5274 - binary_accuracy: 0.8000 - val_loss: 0.6145 - val_binary_accuracy: 0.7000
# Epoch 29/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5149 - binary_accuracy: 0.7789
# Epoch 00029: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.5149 - binary_accuracy: 0.7789 - val_loss: 0.6176 - val_binary_accuracy: 0.6833
# Epoch 30/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4985 - binary_accuracy: 0.8246
# Epoch 00030: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4985 - binary_accuracy: 0.8246 - val_loss: 0.6195 - val_binary_accuracy: 0.6833
# Epoch 31/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4955 - binary_accuracy: 0.7965
# Epoch 00031: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4955 - binary_accuracy: 0.7965 - val_loss: 0.6180 - val_binary_accuracy: 0.6833
# Epoch 32/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4905 - binary_accuracy: 0.8000
# Epoch 00032: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4905 - binary_accuracy: 0.8000 - val_loss: 0.6185 - val_binary_accuracy: 0.6833
# Epoch 33/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4760 - binary_accuracy: 0.7754
# Epoch 00033: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4760 - binary_accuracy: 0.7754 - val_loss: 0.6038 - val_binary_accuracy: 0.6833
# Epoch 34/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4833 - binary_accuracy: 0.8175
# Epoch 00034: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4833 - binary_accuracy: 0.8175 - val_loss: 0.5988 - val_binary_accuracy: 0.6833
# Epoch 35/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4840 - binary_accuracy: 0.8105
# Epoch 00035: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4840 - binary_accuracy: 0.8105 - val_loss: 0.5837 - val_binary_accuracy: 0.7167
# Epoch 36/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4527 - binary_accuracy: 0.8246
# Epoch 00036: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4527 - binary_accuracy: 0.8246 - val_loss: 0.5780 - val_binary_accuracy: 0.7167
# Epoch 37/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5019 - binary_accuracy: 0.8175
# Epoch 00037: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.5019 - binary_accuracy: 0.8175 - val_loss: 0.5764 - val_binary_accuracy: 0.7167
# Epoch 38/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5362 - binary_accuracy: 0.8351
# Epoch 00038: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5362 - binary_accuracy: 0.8351 - val_loss: 0.6040 - val_binary_accuracy: 0.6833
# Epoch 39/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4854 - binary_accuracy: 0.8105
# Epoch 00039: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4854 - binary_accuracy: 0.8105 - val_loss: 0.6325 - val_binary_accuracy: 0.6667
# Epoch 40/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4650 - binary_accuracy: 0.7965
# Epoch 00040: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4650 - binary_accuracy: 0.7965 - val_loss: 0.6297 - val_binary_accuracy: 0.6667
# Epoch 41/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4769 - binary_accuracy: 0.8070
# Epoch 00041: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4769 - binary_accuracy: 0.8070 - val_loss: 0.6161 - val_binary_accuracy: 0.6833
# Epoch 42/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4941 - binary_accuracy: 0.7895
# Epoch 00042: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4941 - binary_accuracy: 0.7895 - val_loss: 0.5950 - val_binary_accuracy: 0.6833
# Epoch 43/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4404 - binary_accuracy: 0.7965
# Epoch 00043: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4404 - binary_accuracy: 0.7965 - val_loss: 0.5999 - val_binary_accuracy: 0.6667
# Epoch 44/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4556 - binary_accuracy: 0.8211
# Epoch 00044: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4556 - binary_accuracy: 0.8211 - val_loss: 0.5995 - val_binary_accuracy: 0.6500
# Epoch 45/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4777 - binary_accuracy: 0.8351
# Epoch 00045: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4777 - binary_accuracy: 0.8351 - val_loss: 0.5949 - val_binary_accuracy: 0.6500
# Epoch 46/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4531 - binary_accuracy: 0.7965
# Epoch 00046: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4531 - binary_accuracy: 0.7965 - val_loss: 0.5914 - val_binary_accuracy: 0.6500
# Epoch 47/100
# 5/4 [=================================] - ETA: 0s - loss: 0.4258 - binary_accuracy: 0.8351
# Epoch 00047: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 16s 3s/step - loss: 0.4258 - binary_accuracy: 0.8351 - val_loss: 0.5766 - val_binary_accuracy: 0.6500
# Epoch 48/100
# 5/4 [=================================] - ETA: -1s - loss: 0.5096 - binary_accuracy: 0.8175
# Epoch 00048: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.5096 - binary_accuracy: 0.8175 - val_loss: 0.5858 - val_binary_accuracy: 0.6333
# Epoch 49/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4758 - binary_accuracy: 0.8070
# Epoch 00049: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4758 - binary_accuracy: 0.8070 - val_loss: 0.6106 - val_binary_accuracy: 0.6500
# Epoch 50/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4832 - binary_accuracy: 0.8351
# Epoch 00050: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4832 - binary_accuracy: 0.8351 - val_loss: 0.6260 - val_binary_accuracy: 0.6500
# Epoch 51/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4753 - binary_accuracy: 0.7825
# Epoch 00051: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.4753 - binary_accuracy: 0.7825 - val_loss: 0.6566 - val_binary_accuracy: 0.6333
# Epoch 52/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4450 - binary_accuracy: 0.7930
# Epoch 00052: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4450 - binary_accuracy: 0.7930 - val_loss: 0.6492 - val_binary_accuracy: 0.6333
# Epoch 53/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4823 - binary_accuracy: 0.7825
# Epoch 00053: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4823 - binary_accuracy: 0.7825 - val_loss: 0.6224 - val_binary_accuracy: 0.6500
# Epoch 54/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4324 - binary_accuracy: 0.8211
# Epoch 00054: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4324 - binary_accuracy: 0.8211 - val_loss: 0.5984 - val_binary_accuracy: 0.6500
# Epoch 55/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4009 - binary_accuracy: 0.8456
# Epoch 00055: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4009 - binary_accuracy: 0.8456 - val_loss: 0.5715 - val_binary_accuracy: 0.6667
# Epoch 56/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4503 - binary_accuracy: 0.8456
# Epoch 00056: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4503 - binary_accuracy: 0.8456 - val_loss: 0.5505 - val_binary_accuracy: 0.6833
# Epoch 57/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4207 - binary_accuracy: 0.8281
# Epoch 00057: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4207 - binary_accuracy: 0.8281 - val_loss: 0.5531 - val_binary_accuracy: 0.6833
# Epoch 58/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4342 - binary_accuracy: 0.8456
# Epoch 00058: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4342 - binary_accuracy: 0.8456 - val_loss: 0.5421 - val_binary_accuracy: 0.6833
# Epoch 59/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4142 - binary_accuracy: 0.8491
# Epoch 00059: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4142 - binary_accuracy: 0.8491 - val_loss: 0.5461 - val_binary_accuracy: 0.6833
# Epoch 60/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4609 - binary_accuracy: 0.8351
# Epoch 00060: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4609 - binary_accuracy: 0.8351 - val_loss: 0.5536 - val_binary_accuracy: 0.6833
# Epoch 61/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4420 - binary_accuracy: 0.7965
# Epoch 00061: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4420 - binary_accuracy: 0.7965 - val_loss: 0.5686 - val_binary_accuracy: 0.6833
# Epoch 62/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4243 - binary_accuracy: 0.8105
# Epoch 00062: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4243 - binary_accuracy: 0.8105 - val_loss: 0.5792 - val_binary_accuracy: 0.6833
# Epoch 63/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4461 - binary_accuracy: 0.8421
# Epoch 00063: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4461 - binary_accuracy: 0.8421 - val_loss: 0.5798 - val_binary_accuracy: 0.6833
# Epoch 64/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4516 - binary_accuracy: 0.8140
# Epoch 00064: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4516 - binary_accuracy: 0.8140 - val_loss: 0.5903 - val_binary_accuracy: 0.6500
# Epoch 65/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4402 - binary_accuracy: 0.8105
# Epoch 00065: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4402 - binary_accuracy: 0.8105 - val_loss: 0.5865 - val_binary_accuracy: 0.6500
# Epoch 66/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4360 - binary_accuracy: 0.8456
# Epoch 00066: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4360 - binary_accuracy: 0.8456 - val_loss: 0.5917 - val_binary_accuracy: 0.6500
# Epoch 67/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3972 - binary_accuracy: 0.8211
# Epoch 00067: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3972 - binary_accuracy: 0.8211 - val_loss: 0.5814 - val_binary_accuracy: 0.6833
# Epoch 68/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4142 - binary_accuracy: 0.8316
# Epoch 00068: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4142 - binary_accuracy: 0.8316 - val_loss: 0.5538 - val_binary_accuracy: 0.6833
# Epoch 69/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4463 - binary_accuracy: 0.8456
# Epoch 00069: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.4463 - binary_accuracy: 0.8456 - val_loss: 0.5535 - val_binary_accuracy: 0.6833
# Epoch 70/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4306 - binary_accuracy: 0.8140
# Epoch 00070: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4306 - binary_accuracy: 0.8140 - val_loss: 0.5625 - val_binary_accuracy: 0.6667
# Epoch 71/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4285 - binary_accuracy: 0.8211
# Epoch 00071: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.4285 - binary_accuracy: 0.8211 - val_loss: 0.5640 - val_binary_accuracy: 0.6833
# Epoch 72/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4190 - binary_accuracy: 0.8772
# Epoch 00072: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4190 - binary_accuracy: 0.8772 - val_loss: 0.5704 - val_binary_accuracy: 0.6833
# Epoch 73/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4103 - binary_accuracy: 0.8491
# Epoch 00073: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4103 - binary_accuracy: 0.8491 - val_loss: 0.5683 - val_binary_accuracy: 0.7000
# Epoch 74/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3919 - binary_accuracy: 0.8632
# Epoch 00074: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3919 - binary_accuracy: 0.8632 - val_loss: 0.5525 - val_binary_accuracy: 0.7000
# Epoch 75/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4115 - binary_accuracy: 0.8491
# Epoch 00075: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.4115 - binary_accuracy: 0.8491 - val_loss: 0.5441 - val_binary_accuracy: 0.7000
# Epoch 76/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4261 - binary_accuracy: 0.8526
# Epoch 00076: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.4261 - binary_accuracy: 0.8526 - val_loss: 0.5408 - val_binary_accuracy: 0.7000
# Epoch 77/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4119 - binary_accuracy: 0.8351
# Epoch 00077: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4119 - binary_accuracy: 0.8351 - val_loss: 0.5428 - val_binary_accuracy: 0.7000
# Epoch 78/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3810 - binary_accuracy: 0.8526
# Epoch 00078: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3810 - binary_accuracy: 0.8526 - val_loss: 0.5443 - val_binary_accuracy: 0.7000
# Epoch 79/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3970 - binary_accuracy: 0.8421
# Epoch 00079: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3970 - binary_accuracy: 0.8421 - val_loss: 0.5385 - val_binary_accuracy: 0.7000
# Epoch 80/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3875 - binary_accuracy: 0.8702
# Epoch 00080: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.3875 - binary_accuracy: 0.8702 - val_loss: 0.5380 - val_binary_accuracy: 0.7000
# Epoch 81/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3906 - binary_accuracy: 0.8351
# Epoch 00081: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3906 - binary_accuracy: 0.8351 - val_loss: 0.5351 - val_binary_accuracy: 0.7000
# Epoch 82/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3979 - binary_accuracy: 0.8596
# Epoch 00082: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3979 - binary_accuracy: 0.8596 - val_loss: 0.5399 - val_binary_accuracy: 0.7000
# Epoch 83/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4233 - binary_accuracy: 0.8386
# Epoch 00083: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4233 - binary_accuracy: 0.8386 - val_loss: 0.5692 - val_binary_accuracy: 0.6833
# Epoch 84/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4101 - binary_accuracy: 0.8175
# Epoch 00084: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 20s 4s/step - loss: 0.4101 - binary_accuracy: 0.8175 - val_loss: 0.5972 - val_binary_accuracy: 0.6667
# Epoch 85/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3717 - binary_accuracy: 0.8351
# Epoch 00085: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.3717 - binary_accuracy: 0.8351 - val_loss: 0.5968 - val_binary_accuracy: 0.6667
# Epoch 86/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4054 - binary_accuracy: 0.8070
# Epoch 00086: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4054 - binary_accuracy: 0.8070 - val_loss: 0.5807 - val_binary_accuracy: 0.6667
# Epoch 87/100
# 5/4 [=================================] - ETA: 0s - loss: 0.4056 - binary_accuracy: 0.8246
# Epoch 00087: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 16s 3s/step - loss: 0.4056 - binary_accuracy: 0.8246 - val_loss: 0.5630 - val_binary_accuracy: 0.6833
# Epoch 88/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3628 - binary_accuracy: 0.8211
# Epoch 00088: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3628 - binary_accuracy: 0.8211 - val_loss: 0.5491 - val_binary_accuracy: 0.7333
# Epoch 89/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4020 - binary_accuracy: 0.8211
# Epoch 00089: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4020 - binary_accuracy: 0.8211 - val_loss: 0.5423 - val_binary_accuracy: 0.7000
# Epoch 90/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3785 - binary_accuracy: 0.8386
# Epoch 00090: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3785 - binary_accuracy: 0.8386 - val_loss: 0.5494 - val_binary_accuracy: 0.7167
# Epoch 91/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3501 - binary_accuracy: 0.8561
# Epoch 00091: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.3501 - binary_accuracy: 0.8561 - val_loss: 0.5314 - val_binary_accuracy: 0.7167
# Epoch 92/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4069 - binary_accuracy: 0.8386
# Epoch 00092: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4069 - binary_accuracy: 0.8386 - val_loss: 0.5174 - val_binary_accuracy: 0.7333
# Epoch 93/100
# 5/4 [=================================] - ETA: 0s - loss: 0.3818 - binary_accuracy: 0.8667
# Epoch 00093: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.3818 - binary_accuracy: 0.8667 - val_loss: 0.5265 - val_binary_accuracy: 0.7333
# Epoch 94/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3569 - binary_accuracy: 0.8667
# Epoch 00094: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.3569 - binary_accuracy: 0.8667 - val_loss: 0.5434 - val_binary_accuracy: 0.7000
# Epoch 95/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4058 - binary_accuracy: 0.8421
# Epoch 00095: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 17s 3s/step - loss: 0.4058 - binary_accuracy: 0.8421 - val_loss: 0.5503 - val_binary_accuracy: 0.7167
# Epoch 96/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3931 - binary_accuracy: 0.8316
# Epoch 00096: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3931 - binary_accuracy: 0.8316 - val_loss: 0.5699 - val_binary_accuracy: 0.7000
# Epoch 97/100
# 5/4 [=================================] - ETA: -1s - loss: 0.4233 - binary_accuracy: 0.8351
# Epoch 00097: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.4233 - binary_accuracy: 0.8351 - val_loss: 0.5790 - val_binary_accuracy: 0.6833
# Epoch 98/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3721 - binary_accuracy: 0.8386
# Epoch 00098: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3721 - binary_accuracy: 0.8386 - val_loss: 0.5781 - val_binary_accuracy: 0.7000
# Epoch 99/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3980 - binary_accuracy: 0.8211
# Epoch 00099: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 18s 4s/step - loss: 0.3980 - binary_accuracy: 0.8211 - val_loss: 0.5623 - val_binary_accuracy: 0.7333
# Epoch 100/100
# 5/4 [=================================] - ETA: -1s - loss: 0.3959 - binary_accuracy: 0.8175
# Epoch 00100: saving model to ./checkpoint_path/final_cnn_transfer/training_2/cp.ckpt
# 5/4 [=================================] - 19s 4s/step - loss: 0.3959 - binary_accuracy: 0.8175 - val_loss: 0.5295 - val_binary_accuracy: 0.7167

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['binary_accuracy']
    val_acc = history.history['val_binary_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy-%')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
plot_learning_curve(history)

# %%
output = load_model('./checkpoint_path/final_cnn_transfer/training_2/model00000099.h5')

# %%
output.compile(loss='binary_crossentropy'
            , optimizer = keras.optimizers.Adam(learning_rate=5e-5), metrics='binary_accuracy')

output.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet152v2 (Model)          (None, 7, 7, 2048)        58331648
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 58,594,049
# Trainable params: 262,401
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
score = output.evaluate(ds_test, steps = len(df_test), verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 2022-09-28 10:08:54.538248: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-09-28 10:08:54.708695: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# Test loss: 0.3878220319747925
# Test accuracy: 0.8730158805847168

# %%
num_label = {'Inflamed': 0, 'NonInflamed' : 1}
Y_test = df_test['class'].copy().map(num_label).astype('int')

# %%
ds_test.reset()
predictions = output.predict(ds_test, steps=len(ds_test), verbose=0)
pred_labels= np.where(predictions>0.5, 1, 0)

# %%
print("Test Accuracy: ", accuracy_score(Y_test, pred_labels))
# Out:
# Test Accuracy:  0.873015873015873

# %%
confusion_matrix = metrics.confusion_matrix(Y_test, pred_labels)
sns.heatmap(confusion_matrix, annot=True, fmt="d")

plt.xlabel("Predicted Label", fontsize= 12)
plt.ylabel("True Label", fontsize= 12)

plt.show()

# %%
print(metrics.classification_report(Y_test, pred_labels, labels = [0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.88      0.64         8
#            1       0.98      0.87      0.92        55
#
#     accuracy                           0.87        63
#    macro avg       0.74      0.87      0.78        63
# weighted avg       0.92      0.87      0.89        63

# %%
roc_auc = metrics.roc_auc_score(Y_test, predictions)
print('ROC_AUC: ', roc_auc)

fpr, tpr, thresholds = metrics.roc_curve(Y_test, predictions)

plt.plot(fpr, tpr, label = 'ROC_AUC = %0.3f' % roc_auc)

plt.xlabel("False Positive Rate", fontsize= 12)
plt.ylabel("True Positive Rate", fontsize= 12)
plt.legend(loc="lower right")

plt.show()
# Out:
# ROC_AUC:  0.8681818181818182

# %%
#Identify all images classified as parasitized
inflamed_image_idx = np.where(pred_labels == 0)[0]

# %%
num_label = {'Inflamed': 0, 'NonInflamed' : 1}
X_test = df_test['image']

# %%
predicted_as_para=[]
for i in inflamed_image_idx:
    par_img = X_test[i]
    #plt.imsave("results_classified_as_para/para_"+str(i)+".png", par_img)
    predicted_as_para.append(par_img)
    
predicted_as_para = np.array(predicted_as_para)

# %%
predicted_as_para = np.array(predicted_as_para)

# %% [markdown]
# # Training_3

# %%
base_model = tf.keras.applications.ResNet152V2(
    weights='imagenet',
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False)

base_model.trainable = False

def get_pretrained():
    
    #Input shape = [width, height, color channels]
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    
    x = base_model(inputs)

    # Head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    
    #Final Layer (Output)
    output = layers.Dense(1, activation='sigmoid')(x)
    
    model = keras.Model(inputs=[inputs], outputs=output)
    
    return model

# %%
# focal loss 
def focal_loss(alpha=0.25,gamma=2.0):
    def focal_crossentropy(y_true, y_pred):
        bce = K.binary_crossentropy(y_true, y_pred)
        
        y_pred = K.clip(y_pred, K.epsilon(), 1.- K.epsilon())
        p_t = (y_true*y_pred) + ((1-y_true)*(1-y_pred))
        
        alpha_factor = 1
        modulating_factor = 1

        alpha_factor = y_true*alpha + ((1-alpha)*(1-y_true))
        modulating_factor = K.pow((1-p_t), gamma)

        # compute the final loss and return
        return K.mean(alpha_factor*modulating_factor*bce, axis=-1)
    return focal_crossentropy

# %%
keras.backend.clear_session()

model_pretrained = get_pretrained()
optimizer = RMSprop(0.0001)
model_pretrained.compile(loss=focal_loss()
              , optimizer = optimizer, metrics='binary_accuracy')

model_pretrained.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet152v2 (Model)          (None, 7, 7, 2048)        58331648
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 58,594,049
# Trainable params: 262,401
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
history = model_pretrained.fit(ds_train,
          batch_size = BATCH, epochs = 10,
          validation_data=ds_valid,
        #   callbacks=[early_stopping, plateau, cp_callback, checkpoint],
          callbacks=[cp_callback, checkpoint],
          class_weight = class_weights,
          steps_per_epoch=(len(df_train)/BATCH),
          validation_steps=(len(df_valid)/BATCH));
# Out:
# Epoch 1/10
# 2022-09-28 11:03:34.665161: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2022-09-28 11:03:35.487869: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 179/178 [==============================] - ETA: -1s - loss: 0.1126 - binary_accuracy: 0.4839
# Epoch 00001: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 390s 2s/step - loss: 0.1126 - binary_accuracy: 0.4839 - val_loss: 0.0660 - val_binary_accuracy: 0.4667
# Epoch 2/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0572 - binary_accuracy: 0.6372
# Epoch 00002: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 359s 2s/step - loss: 0.0572 - binary_accuracy: 0.6372 - val_loss: 0.0527 - val_binary_accuracy: 0.6833
# Epoch 3/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0455 - binary_accuracy: 0.7143
# Epoch 00003: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 334s 2s/step - loss: 0.0455 - binary_accuracy: 0.7143 - val_loss: 0.0517 - val_binary_accuracy: 0.7000
# Epoch 4/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0382 - binary_accuracy: 0.7666
# Epoch 00004: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 333s 2s/step - loss: 0.0382 - binary_accuracy: 0.7666 - val_loss: 0.0515 - val_binary_accuracy: 0.6500
# Epoch 5/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0334 - binary_accuracy: 0.7996
# Epoch 00005: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 331s 2s/step - loss: 0.0334 - binary_accuracy: 0.7996 - val_loss: 0.0563 - val_binary_accuracy: 0.7333
# Epoch 6/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0311 - binary_accuracy: 0.8124
# Epoch 00006: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 333s 2s/step - loss: 0.0311 - binary_accuracy: 0.8124 - val_loss: 0.0571 - val_binary_accuracy: 0.7167
# Epoch 7/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0269 - binary_accuracy: 0.8505
# Epoch 00007: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 334s 2s/step - loss: 0.0269 - binary_accuracy: 0.8505 - val_loss: 0.0605 - val_binary_accuracy: 0.7167
# Epoch 8/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0259 - binary_accuracy: 0.8524
# Epoch 00008: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 333s 2s/step - loss: 0.0259 - binary_accuracy: 0.8524 - val_loss: 0.0606 - val_binary_accuracy: 0.7667
# Epoch 9/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0236 - binary_accuracy: 0.8663
# Epoch 00009: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 337s 2s/step - loss: 0.0236 - binary_accuracy: 0.8663 - val_loss: 0.0630 - val_binary_accuracy: 0.7333
# Epoch 10/10
# 179/178 [==============================] - ETA: -1s - loss: 0.0219 - binary_accuracy: 0.8819
# Epoch 00010: saving model to ./checkpoint_path/final_cnn_transfer/training_3/cp.ckpt
# 179/178 [==============================] - 339s 2s/step - loss: 0.0219 - binary_accuracy: 0.8819 - val_loss: 0.0666 - val_binary_accuracy: 0.7500

# %%
# plot learning curve
def plot_learning_curve(history):
    acc = history.history['binary_accuracy']
    val_acc = history.history['val_binary_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(len(acc))

    plt.plot(epochs, acc, label='training acc')
    plt.plot(epochs, val_acc, label='validation acc')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy-%')
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, label='training loss')
    plt.plot(epochs, val_loss, label='validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
plot_learning_curve(history)

# %%
score = model_pretrained.evaluate(ds_test, steps = len(df_test), verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.04600038379430771
# Test accuracy: 0.8730158805847168

# %%
num_label = {'Inflamed': 0, 'NonInflamed' : 1}
Y_test = df_test['class'].copy().map(num_label).astype('int')

# %%
ds_test.reset()
predictions = model_pretrained.predict(ds_test, steps=len(ds_test), verbose=0)
pred_labels= np.where(predictions>0.5, 1, 0)

# %%
print("Test Accuracy: ", accuracy_score(Y_test, pred_labels))
# Out:
# Test Accuracy:  0.873015873015873

# %%
confusion_matrix = metrics.confusion_matrix(Y_test, pred_labels)
sns.heatmap(confusion_matrix, annot=True, fmt="d")

plt.xlabel("Predicted Label", fontsize= 12)
plt.ylabel("True Label", fontsize= 12)

plt.show()

# %%
print(metrics.classification_report(Y_test, pred_labels, labels = [0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         8
#            1       0.93      0.93      0.93        55
#
#     accuracy                           0.87        63
#    macro avg       0.71      0.71      0.71        63
# weighted avg       0.87      0.87      0.87        63

# %%
roc_auc = metrics.roc_auc_score(Y_test, predictions)
print('ROC_AUC: ', roc_auc)

fpr, tpr, thresholds = metrics.roc_curve(Y_test, predictions)

plt.plot(fpr, tpr, label = 'ROC_AUC = %0.3f' % roc_auc)

plt.xlabel("False Positive Rate", fontsize= 12)
plt.ylabel("True Positive Rate", fontsize= 12)
plt.legend(loc="lower right")

plt.show()
# Out:
# ROC_AUC:  0.7613636363636364

# %%
output_1 = load_model('./checkpoint_path/training_2/model00000200.h5')

# %%
output_1.compile(loss='binary_crossentropy'
            , optimizer = keras.optimizers.Adam(learning_rate=5e-5), metrics='binary_accuracy')

output_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet152v2 (Model)          (None, 7, 7, 2048)        58331648
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               262272
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 58,594,049
# Trainable params: 262,401
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
score = output_1.evaluate(ds_test, steps = len(df_test), verbose = 0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.25276386737823486
# Test accuracy: 0.930232584476471

# %%
num_label = {'Inflamed': 0, 'NonInflamed' : 1}
Y_test = df_test['class'].copy().map(num_label).astype('int')

# %%
ds_test.reset()
predictions = output_1.predict(ds_test, steps=len(ds_test), verbose=0)
pred_labels= np.where(predictions>0.5, 1, 0)

# %%
print("Test Accuracy: ", accuracy_score(Y_test, pred_labels))
# Out:
# Test Accuracy:  0.9302325581395349

# %%
confusion_matrix = metrics.confusion_matrix(Y_test, pred_labels)
sns.heatmap(confusion_matrix, annot=True, fmt="d")

plt.xlabel("Predicted Label", fontsize= 12)
plt.ylabel("True Label", fontsize= 12)

plt.show()

# %%
print(metrics.classification_report(Y_test, pred_labels, labels = [0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       0.97      0.95      0.96        37
#
#     accuracy                           0.93        43
#    macro avg       0.84      0.89      0.86        43
# weighted avg       0.94      0.93      0.93        43

# %%
roc_auc = metrics.roc_auc_score(Y_test, predictions)
print('ROC_AUC: ', roc_auc)

fpr, tpr, thresholds = metrics.roc_curve(Y_test, predictions)

plt.plot(fpr, tpr, label = 'ROC_AUC = %0.3f' % roc_auc)

plt.xlabel("False Positive Rate", fontsize= 12)
plt.ylabel("True Positive Rate", fontsize= 12)
plt.legend(loc="lower right")

plt.show()
# Out:
# ROC_AUC:  0.891891891891892
